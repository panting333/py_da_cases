# %%
#在v1的基础上，增加使用Pandas中数据的聚合和分组功能，pivot_table()、group_by()等函数
#由直方图转为饼图展现不同因素对生存率的影响 pie()
import pandas as pd
import numpy as np
from pandas import Series,DataFrame
from numpy.random import randn,rand
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#男女性生存比例

survived_sex=pd.pivot_table(data,index=['Sex'],columns=['Survived'],values=['PassengerId'],aggfunc=['count'])

# %%
survived_sex
# Out:
#                count
#          PassengerId
# Survived           0    1
# Sex
# female            81  233
# male             468  109

# %%
survived_sex=survived_sex.rename(columns={0:'unsurvived',1:'survived'},level='Survived')

# %%
survived_sex=survived_sex['count']['PassengerId']

# %%
survived_sex
# Out:
# Survived  unsurvived  survived
# Sex
# female            81       233
# male             468       109

# %%
survived_sex['rate']=survived_sex['survived']/survived_sex.sum(axis=1)

# %%
survived_sex
# Out:
# Survived  unsurvived  survived      rate
# Sex
# female            81       233  0.742038
# male             468       109  0.188908

# %%
survived_sex['rate_pct']=survived_sex['rate'].apply(lambda x:format(x,'.2%'))

# %%
survived_sex
# Out:
# Survived  unsurvived  survived      rate rate_pct
# Sex
# female            81       233  0.742038   74.20%
# male             468       109  0.188908   18.89%

# %%
fig,axes=plt.subplots(1,2)

# %%
plt.rcParams['font.sans-serif']=['SimHei']#解决中文乱码,使用指定的汉字字体类型（此处为黑体）
#画出饼图
labels=['遇难','存活']
sizes_m=[468,109]#男性每块对应的数值
sizes_f=[81,233]#女性每块对应的数值
colors=['red','lightskyblue']#每块对应的颜色
explode=(0.1,0.1)#将每一块分割出来，值越大分割出的间隙越大
axes[0].pie(sizes_m,
        colors=colors,
        labels=labels,
        explode=explode,
        autopct='%.2f%%',#数值设置为保留固定小数位的百分数
        shadow=False,#无阴影设置
        startangle=90,#逆时针起始角度设置
        pctdistance=0.5,#数值距圆心半径背书距离
        labeldistance =1.05#图例距圆心半径倍距离
       )#男性存活遇难饼图
axes[0].axis('equal')#x,y轴刻度一致，保证饼图为圆形
axes[0].legend(loc='best')
axes[0].set_title('男性存活/遇难饼图')
# Out:
# Text(0.5, 1, '男性存活/遇难饼图')

# %%
axes[1].pie(sizes_f,
        colors=colors,
        labels=labels,
        explode=explode,
        autopct='%.2f%%',#数值设置为保留固定小数位的百分数
        shadow=False,#无阴影设置
        startangle=180,#逆时针起始角度设置
        pctdistance=0.5,#数值距圆心半径背书距离
        labeldistance =1.05#图例距圆心半径倍距离
       )#女性存活遇难饼图
axes[1].axis('equal')#x,y轴刻度一致，保证饼图为圆形
axes[1].set_title('女性存活/遇难饼图')
axes[1].legend(loc='best')

# %%
fig.savefig('Titanic_survival_sex.jpg',dpi=200)

# %%
#不同等级船舱的生存人数
survived_pclass=pd.pivot_table(data,index=['Survived'],columns=['Pclass'],values=['PassengerId'],aggfunc='count')

# %%
survived_pclass=survived_pclass['PassengerId']

# %%
survived_pclass
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
survived_pclass=survived_pclass.rename(index={0:'遇难',1:'获救'},columns={1:'一等舱',2:'二等舱',3:'三等舱'})

# %%
survived_pclass
# Out:
# Pclass    一等舱  二等舱  三等舱
# Survived
# 遇难         80   97  372
# 获救        136   87  119

# %%
#不同等级船舱的男女获救率
survived_pclass_sex=pd.pivot_table(data,index=['Survived'],columns=['Pclass','Sex'],values=['PassengerId'],aggfunc='count')

# %%
survived_pclass_sex=survived_pclass_sex['PassengerId']

# %%
survived_pclass_sex
# Out:
# Pclass        1           2           3
# Sex      female male female male female male
# Survived
# 0             3   77      6   91     72  300
# 1            91   45     70   17     72   47

# %%
survived_pclass_sex.loc['sur_rate']=survived_pclass_sex.loc[1]/survived_pclass_sex.sum(axis=0)

# %%
survived_pclass_sex
# Out:
# Pclass            1                     2                 3
# Sex          female       male     female       male female        male
# Survived
# 0          3.000000  77.000000   6.000000  91.000000   72.0  300.000000
# 1         91.000000  45.000000  70.000000  17.000000   72.0   47.000000
# sur_rate   0.968085   0.368852   0.921053   0.157407    0.5    0.135447

# %%
fig1,axes1=plt.subplots(1,3)
fig1.subplots_adjust(wspace=0.8,hspace=1.1)

# %%
for col,ax in zip(survived_pclass.columns,range(3)):
        sizes=survived_pclass[col].values
        axes1[ax].pie(sizes,colors=colors,labels=labels,explode=explode,autopct='%.2f%%',shadow=True,startangle=90,pctdistance=0.5,labeldistance=1)
        axes1[ax].axis('equal')#x,y轴刻度一致，保证饼图为圆形
        axes1[ax].set_title(col+'存活/遇难饼图')
        axes1[ax].legend(loc='best')

# %%
fig1.savefig('Titanic_survival_pclass.jpg',dpi=200)

# %%
#不同年龄的生存人数
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data_with_age=data[data['Age'].notnull()]#筛选出有明确年龄值的数据

# %%
data_with_age
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.cut(data_with_age['Age'],[0,6,12,17,45,69,100],labels=['婴幼儿','少年','青少年','青年','中年','老年'])
# Out:
# 0      青年
# 1      青年
# 2      青年
# 3      青年
# 4      青年
#        ..
# 885    青年
# 886    青年
# 887    青年
# 889    青年
# 890    青年
# Name: Age, Length: 714, dtype: category
# Categories (6, object): [婴幼儿 < 少年 < 青少年 < 青年 < 中年 < 老年]

# %%
data_with_age['Age_cate']=pd.cut(data_with_age['Age'],[0,6,12,17,45,69,100],labels=['婴幼儿','少年','青少年','青年','中年','老年'])
# Out:
# D:\application_setup\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_with_age.groupby('Age_cate')['PassengerId'].count()
# Out:
# Age_cate
# 婴幼儿     47
# 少年      22
# 青少年     44
# 青年     498
# 中年      96
# 老年       7
# Name: PassengerId, dtype: int64

# %%
survived_age=data_with_age.pivot_table(index=['Survived'],columns=['Age_cate'],values=['PassengerId'],aggfunc='count')

# %%
survived_age=survived_age['PassengerId']

# %%
survived_age
# Out:
# Age_cate  婴幼儿  少年  青少年   青年  中年  老年
# Survived
# 0          14  15   23  307  59   6
# 1          33   7   21  191  37   1

# %%
fig,axes=plt.subplots(2,3,figsize=(8,8))
#fig.subplots_adjust(wspace=2,hspace=2)

# %%
for i in range(2):
    if i<1:
             for col,j in zip(survived_age.columns[:3],range(3)):
                     sizes=survived_age[col].values
                     axes[i][j].pie(sizes,colors=colors,labels=labels,explode=explode,autopct='%.2f%%',shadow=True,startangle=90,pctdistance=0.5,labeldistance=1)
                     axes[i][j].axis('equal')#x,y轴刻度一致，保证饼图为圆形
                     axes[i][j].set_title(col+'遇难率饼图')
                     axes[i][j].legend(loc='best')
    elif i>0 :
        for col,j in zip(survived_age.columns[3:],range(3)):
            sizes=survived_age[col].values
            axes[i][j].pie(sizes,colors=colors,labels=labels,explode=explode,autopct='%.2f%%',shadow=True,startangle=90,pctdistance=0.5,labeldistance=1)
            axes[i][j].axis('equal')#x,y轴刻度一致，保证饼图为圆形
            axes[i][j].set_title(col+'遇难率饼图')
            axes[i][j].legend(loc='best')

# %%
fig
